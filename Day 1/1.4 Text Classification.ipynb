# %% [markdown]
# <h1 align=center>Text Classification</h1>
#
# This is our `hello world` example

# %%
# a helper functions and imports
from IPython.display import display
def highlight_col(x, df):
    #set by condition
    mask =  df['label'] == 'pos'
    mask2 = df['label'] == 'neg'
    x = pd.DataFrame('', index=df.index, columns=df.columns)
    x.loc[mask] = 'background-color: #e6ffe6'
    x.loc[mask2] = 'background-color: #ffe6e6'
    return x

# %% [markdown]
# ## Load the data

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

train_pos = pd.read_csv("data/train_Arabic_tweets_positive_20190413.tsv",
                        sep='\t', header=None)
train_neg = pd.read_csv("data/train_Arabic_tweets_negative_20190413.tsv",
                        sep='\t', header=None)
train_data = pd.concat([train_pos, train_neg], ignore_index=True)
train_data.columns = ['label', 'tweet']
del train_pos, train_neg

pd.set_option('display.max_colwidth', 100000)
df_tmp = train_data.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_c7fcb_row0_col0, #T_c7fcb_row0_col1 {
#   background-color: #e6ffe6;
# }
# #T_c7fcb_row1_col0, #T_c7fcb_row1_col1, #T_c7fcb_row2_col0, #T_c7fcb_row2_col1, #T_c7fcb_row3_col0, #T_c7fcb_row3_col1, #T_c7fcb_row4_col0, #T_c7fcb_row4_col1 {
#   background-color: #ffe6e6;
# }
# </style>
# <table id="T_c7fcb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >label</th>
#       <th class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7fcb_level0_row0" class="row_heading level0 row0" >18151</th>
#       <td id="T_c7fcb_row0_col0" class="data row0 col0" >pos</td>
#       <td id="T_c7fcb_row0_col1" class="data row0 col1" >بمناسبة فوز #الهلال 💙💙 سحب على مبلغ مالي 💰 شروط المسابقة : • رتويت للتغريدة • متابعة : السحب من الرتوي…</td>
#     </tr>
#     <tr>
#       <th id="T_c7fcb_level0_row1" class="row_heading level0 row1" >44683</th>
#       <td id="T_c7fcb_row1_col0" class="data row1 col0" >neg</td>
#       <td id="T_c7fcb_row1_col1" class="data row1 col1" >#تسكر لي عيونه #وعيونه الليله #تجاوبني قبل #اشوفه واسأل #يا اطهر ذنب #احبه ذنب #وادعيله لنفس #احيان ما تتقارن ب…</td>
#     </tr>
#     <tr>
#       <th id="T_c7fcb_level0_row2" class="row_heading level0 row2" >40009</th>
#       <td id="T_c7fcb_row2_col0" class="data row2 col0" >neg</td>
#       <td id="T_c7fcb_row2_col1" class="data row2 col1" >وفاة الشاب الخلوق محمد أبو شملة 💔 إثر سقوطه من الطابق الرابع أثناء ملاحقة الشرطة التركية له و لعدد من الشباب المه…</td>
#     </tr>
#     <tr>
#       <th id="T_c7fcb_level0_row3" class="row_heading level0 row3" >25912</th>
#       <td id="T_c7fcb_row3_col0" class="data row3 col0" >neg</td>
#       <td id="T_c7fcb_row3_col1" class="data row3 col1" >عندما كان الهاتف ☎️ مربوطا بسلك . . كان البشر أكثر حرية 😔 #سہااڕۿ</td>
#     </tr>
#     <tr>
#       <th id="T_c7fcb_level0_row4" class="row_heading level0 row4" >36763</th>
#       <td id="T_c7fcb_row4_col0" class="data row4 col0" >neg</td>
#       <td id="T_c7fcb_row4_col1" class="data row4 col1" >للمجاراه بين الزعل والرضى تاهت مشاعرنا ان جيت كلك رضى وان رحت كلك زعل — ياهيه تكفى دخيلك بس عبرنا اعطيك شحم الوعل و…</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_pos = pd.read_csv("data/test_Arabic_tweets_positive_20190413.tsv",
                        sep='\t', header=None)
test_neg = pd.read_csv("data/test_Arabic_tweets_negative_20190413.tsv",
                        sep='\t', header=None)
test_data = pd.concat([test_pos, test_neg], ignore_index=True)
test_data.columns = ['label', 'tweet']
del test_pos, test_neg

df_tmp = test_data.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_f0bc7_row0_col0, #T_f0bc7_row0_col1, #T_f0bc7_row2_col0, #T_f0bc7_row2_col1, #T_f0bc7_row3_col0, #T_f0bc7_row3_col1, #T_f0bc7_row4_col0, #T_f0bc7_row4_col1 {
#   background-color: #e6ffe6;
# }
# #T_f0bc7_row1_col0, #T_f0bc7_row1_col1 {
#   background-color: #ffe6e6;
# }
# </style>
# <table id="T_f0bc7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >label</th>
#       <th class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0bc7_level0_row0" class="row_heading level0 row0" >41</th>
#       <td id="T_f0bc7_row0_col0" class="data row0 col0" >pos</td>
#       <td id="T_f0bc7_row0_col1" class="data row0 col1" >#وش_يقول_الليل " " ذا الليل ل أحد يسولف عن هوى باله .. فيني من الشوق ضيق و دمعه و غصه " اللي ل حااله يسولف…</td>
#     </tr>
#     <tr>
#       <th id="T_f0bc7_level0_row1" class="row_heading level0 row1" >7893</th>
#       <td id="T_f0bc7_row1_col0" class="data row1 col0" >neg</td>
#       <td id="T_f0bc7_row1_col1" class="data row1 col1" >اللهم لنا أحبة تحت التراب أشتاق القلب لهم واشتاقت العين لرؤيتهم فإغفر لهم وجعل قبورهم روضة من رياض الجنة 😢 اللهم اج…</td>
#     </tr>
#     <tr>
#       <th id="T_f0bc7_level0_row2" class="row_heading level0 row2" >4703</th>
#       <td id="T_f0bc7_row2_col0" class="data row2 col0" >pos</td>
#       <td id="T_f0bc7_row2_col1" class="data row2 col1" >السحب الليلة على الايفون .. رتويت للمرفقة وطبق الشروط 👇</td>
#     </tr>
#     <tr>
#       <th id="T_f0bc7_level0_row3" class="row_heading level0 row3" >1768</th>
#       <td id="T_f0bc7_row3_col0" class="data row3 col0" >pos</td>
#       <td id="T_f0bc7_row3_col1" class="data row3 col1" >اذا وصلتو لطريق النجاح طرشولي اللوكيشن 😂</td>
#     </tr>
#     <tr>
#       <th id="T_f0bc7_level0_row4" class="row_heading level0 row4" >5001</th>
#       <td id="T_f0bc7_row4_col0" class="data row4 col0" >pos</td>
#       <td id="T_f0bc7_row4_col1" class="data row4 col1" >:40 الوضع امان الحمدلله .. ماف انباء عن اصابات لحدي اللحظة 🚨 🔴 الحصل انو في كجر مندس ضرب رصاص بالتزامن مع قناص ق…</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Baseline model (using pipeline)

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline

vec = CountVectorizer()
clf = LogisticRegression()
pipe = make_pipeline(vec, clf)
pipe.fit(train_data.tweet, train_data.label);
# Out:
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Let's test this basic model

# %%
from sklearn import metrics

def print_report(pipe, x_test, y_test):
    y_pred = pipe.predict(x_test)
    report = metrics.classification_report(y_test, y_pred)
    print(report)
    print("accuracy: {:0.3f}".format(metrics.accuracy_score(y_test, y_pred)))

print_report(pipe, test_data.tweet, test_data.label)
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.77      0.82      0.80      5768
#          pos       0.81      0.76      0.78      5752
#
#     accuracy                           0.79     11520
#    macro avg       0.79      0.79      0.79     11520
# weighted avg       0.79      0.79      0.79     11520
#
# accuracy: 0.792

# %% [markdown]
# ## let's take a look inside the model

# %%
import eli5
eli5.show_weights(clf, vec=vec, top=20)
# Out:
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.779
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الإخونج
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.414
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         وصباحك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.216
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         هالسنه
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.093
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ابريل
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.092
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         السحب
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.086
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الزرقاء
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.075
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         برونو
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.029
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         اللوك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.887
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الطيب
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.880
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         حكمة
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.862
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مبروك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.813
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ريهام
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 85.17%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 36163 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 85.31%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 34674 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 85.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.788
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مناحل_ابو_سلطان
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.819
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         فاتني
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.822
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         خرووج
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.988
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         يستر
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.138
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         زعيم_تويتر_فولورز_اهلاوي
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 82.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.218
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مسلسل_ودك_يتكرر_برمضان
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 82.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.253
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         أجباري_وليس_أختياري
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 81.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.534
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         امطار_الشرقيه
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# ## Try our model on some tweets

# %%
for _, row in test_data.sample(5).iterrows():
    print(f"true label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vec,))
    print("--"*50)
# Out:
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.531</b>, score <b>0.124</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.458
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 83.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">احمم </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.458">عالي</span><span style="opacity: 0.80">* ☺</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.959</b>, score <b>-3.149</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.815
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 75.46%); opacity: 0.90" title="0.475">مافي</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 68.67%); opacity: 0.94" title="0.673">فايدة</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.954">نايمة</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.03%); opacity: 0.80" title="-0.005">من</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.05%); opacity: 0.87" title="0.353">وقت</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.72%); opacity: 0.80" title="0.016">ولا</span><span style="opacity: 0.80"> متاخر ناشة </span><span style="background-color: hsl(0, 100.00%, 99.03%); opacity: 0.80" title="-0.005">من</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 80.05%); opacity: 0.87" title="0.353">وقت</span><span style="opacity: 0.80"> ناشة 😅</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.852</b>, score <b>-1.752</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.418
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">الأهتمام </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.704">بدايه</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.99%); opacity: 0.82" title="-0.084">التعلق</span><span style="opacity: 0.80"> 😏 و </span><span style="background-color: hsl(120, 100.00%, 68.83%); opacity: 0.94" title="0.493">الغيره</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.704">بدايه</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.35%); opacity: 0.83" title="-0.106">الحب</span><span style="opacity: 0.80"> ❤️ و الأتنين نهايتهم </span><span style="background-color: hsl(0, 100.00%, 83.73%); opacity: 0.86" title="-0.195">سوده</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.93%); opacity: 0.83" title="-0.098">على</span><span style="opacity: 0.80"> دماغنا 😂😂</span>
#     </p>
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ----------------------------------------------------------------------------------------------------
# true label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.996</b>, score <b>5.586</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.919
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="2.092">السحب</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.12%); opacity: 0.81" title="0.075">الليلة</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.30%); opacity: 0.81" title="0.098">على</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.68%); opacity: 0.80" title="-0.036">الايفون</span><span style="opacity: 0.80"> .. </span><span style="background-color: hsl(120, 100.00%, 74.79%); opacity: 0.90" title="1.082">رتويت</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.94%); opacity: 0.85" title="0.568">للمرفقة</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.94%); opacity: 0.85" title="0.568">وطبق</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 68.72%); opacity: 0.94" title="1.472">الشروط</span><span style="opacity: 0.80"> 👇</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: neg
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.629</b>, score <b>-0.528</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.334
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.195
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 74.26%); opacity: 0.91" title="0.372">مورننج</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.56%); opacity: 0.81" title="0.030">علي</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 74.26%); opacity: 0.91" title="0.372">الاهلويه</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 76.59%); opacity: 0.89" title="0.325">بس</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-0.698">صباح</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.20%); opacity: 0.82" title="-0.055">ال</span><span style="opacity: 0.80"> /٠ </span><span style="background-color: hsl(120, 100.00%, 74.92%); opacity: 0.90" title="0.358">ان</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 79.86%); opacity: 0.88" title="-0.262">شاء</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 80.69%); opacity: 0.87" title="-0.247">الله</span><span style="opacity: 0.80"> 💣</span>
#     </p>
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Try Tfidf with some processing

# %%
vec = TfidfVectorizer(analyzer='char_wb', ngram_range=(3, 5), min_df=.01, max_df=.3)
clf = LinearSVC()
pipe_tfidf = make_pipeline(vec, clf)
pipe_tfidf.fit(train_data.tweet, train_data.label)
# Out:
# Pipeline(steps=[('tfidfvectorizer',
#                  TfidfVectorizer(analyzer='char_wb', max_df=0.3, min_df=0.01,
#                                  ngram_range=(3, 5))),
#                 ('linearsvc', LinearSVC())])

# %%
print_report(pipe_tfidf, test_data.tweet, test_data.label)
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.85      0.82      0.84      5768
#          pos       0.83      0.86      0.84      5752
#
#     accuracy                           0.84     11520
#    macro avg       0.84      0.84      0.84     11520
# weighted avg       0.84      0.84      0.84     11520
#
# accuracy: 0.838

# %%
eli5.show_weights(clf, vec=vec, top=20)
# Out:
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.905
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>😂<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.245
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>💙<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.222
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>💛<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.580
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>🌹<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.866
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>🤣<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.858
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>❤<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.727
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>😍<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.864
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         تويت<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.555
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(120, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>💪<span style="background-color: hsl(120, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 93.56%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 772 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.45%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 741 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 93.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.618
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(0, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>😏<span style="background-color: hsl(0, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.175
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         <span style="background-color: hsl(0, 80%, 70%); margin: 0 0.1em 0 0" title="A space symbol">&emsp;</span>:(<span style="background-color: hsl(0, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.50%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.175
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         :(<span style="background-color: hsl(0, 80%, 70%); margin: 0 0 0 0.1em" title="A space symbol">&emsp;</span>
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.312
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         لال<span style="background-color:

# %%
for _, row in test_data.sample(5).iterrows():
    print(f"true label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vec,))
    print("--"*50)
# Out:
# true label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-0.398</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.483
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 94.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 95.23%); opacity: 0.81" title="0.003">ع</span><span style="background-color: hsl(120, 100.00%, 82.64%); opacity: 0.86" title="0.019">ب</span><span style="background-color: hsl(0, 100.00%, 74.21%); opacity: 0.91" title="-0.033">د</span><span style="background-color: hsl(0, 100.00%, 86.56%); opacity: 0.84" title="-0.013">ا</span><span style="background-color: hsl(120, 100.00%, 98.03%); opacity: 0.80" title="0.001">ل</span><span style="background-color: hsl(0, 100.00%, 77.94%); opacity: 0.89" title="-0.026">ل</span><span style="background-color: hsl(120, 100.00%, 93.21%); opacity: 0.82" title="0.005">ه</span><span style="background-color: hsl(120, 100.00%, 90.88%); opacity: 0.82" title="0.007"> </span><span style="background-color: hsl(0, 100.00%, 89.81%); opacity: 0.83" title="-0.009">ب</span><span style="background-color: hsl(0, 100.00%, 82
><span style="background-color: hsl(0, 100.00%, 88.09%); opacity: 0.84" title="-0.009">ه</span><span style="background-color: hsl(0, 100.00%, 80.83%); opacity: 0.87" title="-0.017"> </span><span style="background-color: hsl(120, 100.00%, 75.38%); opacity: 0.90" title="0.025">بس</span><span style="background-color: hsl(120, 100.00%, 64.52%); opacity: 0.97" title="0.041"> </span><span style="background-color: hsl(120, 100.00%, 61.53%); opacity: 0.99" title="0.046">ل</span><span style="background-color: hsl(120, 100.00%, 63.05%); opacity: 0.98" title="0.044">ي</span><span style="background-color: hsl(120, 100.00%, 85.52%); opacity: 0.85" title="0.011">ه</span><span style="background-color: hsl(120, 100.00%, 73.21%); opacity: 0.91" title="0.028"> </span><span style="opacity: 0.80">اگ</span><span style="background-color: hsl(120, 100.00%, 75.81%); opacity: 0.90" title="0.024">تر </span><span style="opacity: 0.80">م</span><span style="background-color: hsl(120, 100.00%, 77.63%); opacity: 0.89" title="0.02 ...
# ----------------------------------------------------------------------------------------------------
# true label: pos
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (score <b>1.446</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.362
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 88.68%); opacity: 0.83" title="0.056">م</span><span style="background-color: hsl(120, 100.00%, 85.48%); opacity: 0.85" title="0.080">ب</span><span style="background-color: hsl(120, 100.00%, 89.52%); opacity: 0.83" title="0.051">ر</span><span style="background-color: hsl(120, 100.00%, 82.35%); opacity: 0.86" title="0.106">و</span><span style="background-color: hsl(120, 100.00%, 89.96%); opacity: 0.83" title="0.047">ك</span><span style="background-color: hsl(120, 100.00%, 90.11%); opacity: 0.83" title="0.047"> </span><span style="background-color: hsl(120, 100.00%, 97.86%); opacity: 0.80" title="0.005">ال</span><span style="background-color: hsl(0, 100.00%, 98.09%); opacity: 0.80" title="-0.004">ف</span><span style="background-color: hsl(120, 100.00%, 90.31%); opacity: 0.83" title="0.045">وز</span><span style="background-color: hsl(0, 100.00%, 85.46%); opacity: 0.85" title="-0.081"> </span><span style="background-color: hsl(0, 100.00%, 96.19%); opacity: 0.81" title="-0.012">وص</span><span style="background-color: hsl(120, 100.00%, 92.38%); opacity: 0.82" title="0.032">دا</span><span style="background-color: hsl(120, 100.00%, 95.12%); opacity: 0.81" title="0.017">ر</span><span style="background-color: hsl(0, 100.00%, 95.50%); opacity: 0.81" title="-0.015">ه</span><span style="background-color: hsl(120, 100.00%, 99.27%); opacity: 0.80" title="0.001"> </span><span style="background-color: hsl(0, 100.00%, 90.03%); opacity: 0.83" title="-0.047">بس</span><span style="background-color: hsl(120, 100.00%, 61.43%); opacity: 0.99" title="0.325"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.342">💙</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# true label: pos
# C:\Users\Abdelrahman\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (score <b>0.616</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.531
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.084
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 74.91%); opacity: 0.90" title="0.068">ج</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.132">م</span><span style="background-color: hsl(120, 100.00%, 67.52%); opacity: 0.95" title="0.098">ا</span><span style="background-color: hsl(120, 100.00%, 86.86%); opacity: 0.84" title="0.027">ه</span><span style="background-color: hsl(0, 100.00%, 83.41%); opacity: 0.86" title="-0.038">ي</span><span style="background-color: hsl(0, 100.00%, 99.48%); opacity: 0.80" title="-0.000">ر</span><span style="background-color: hsl(120, 100.00%, 87.75%); opacity: 0.84" title="0.024"> </span><span style="background-color: hsl(120, 100.00%, 93.79%); opacity: 0.81" title="0.009">ا</span><span style="background-color: hsl(0, 100.00%, 89.64%); opacity: 0.83" title="-0.019">ل</span><span style="background-color: hsl(120, 100.00%, 92.25%); opacity: 0.82" title="0.013">ه</span><span style="background-color: hsl(120, 100.00%, 91.46%); opacity: 0.82" title="0.015">ل</span><span style="background-color: hsl(120, 100.00%, 84.32%); opacity: 0.85" title="0.035">ا</span><span style="background-color: hsl(120, 100.00%, 92.62%); opacity: 0.82" title="0.012">ل</span><span style="background-color: hsl(0, 100.00%, 76.30%); opacity: 0.89" title="-0.063"> </span><span style="background-color: hsl(120, 100.00%, 89.76%); opacity: 0.83" title="0.019">تر</span><span style="background-color: hsl(120, 100.00%, 99.58%); opacity: 0.80" title="0.000">دد</span><span style="background-color: hsl(0, 100.00%, 79.43%); opacity: 0.88" title="-0.051"> </span><span style="background-color: hsl(0, 100.00%, 79.37%); opacity: 0.88" title="-0.051">نش</span><span style="background-color: hsl(120, 100.00%, 87.66%); opacity: 0.84" title="0.025">يد</span><span style="background-color: hsl(120, 100.00%, 81.59%); opacity: 0.87" title="0.044"> </span><span style="background-color: hsl(120, 100.00%, 87.24%); opacity: 0.84" title="0.026">#</span><span style="background-color: hsl(0, 100.00%, 80.58%); opacity: 0.87" title="-0.047">ا</span><span style="background-color: hsl(0, 100.00%, 95.95%); opacity: 0.81" title="-0.005">ل</span><span style="background-color: hsl(0, 100.00%, 93.35%); opacity: 0.82" title="-0.010">ا</span><span style="background-color: hsl(0, 100.00%, 80.52%); opacity: 0.87" title="-0.047">ت</span><span style="background-color: hsl(120, 100.00%, 88.99%); opacity: 0.83" title="0.021">ح</span><span style="background-color: hsl(0, 100.00%, 87.84%); opacity: 0.84" title="-0.024">ا</span><span style="background-color: hsl(120, 100.00%, 84.77%); opacity: 0.85" title="0.033">د</span><span style="background-color: hsl(120, 100.00%, 73.82%); opacity: 0.91" title="0.072"> </span><span style="background-color: hsl(0, 100.00%, 95.28%); opacity: 0.81" title="-0.006">ب</span><span style="background-color: hsl(0, 100.00%, 97.57%); opacity: 0.80" title="-0.002">ع</span><span style="background-color: hsl(120, 100.00%, 91.51%); opacity: 0.82" title="0.014">د</span><span style="background-color: hsl(0, 100.00%, 96.38%); opacity: 0.81" title="-0.004"> </span><span style="background-color: hsl(120, 100.00%, 84.22%); opacity: 0.85" title="0.035">م</span><span style="background-color: hsl(120, 100.00%, 78.08%); opacity: 0.88" title="0.056">ب</span><span style="background-color: hsl(120, 100.00%, 91.21%); opacity: 0.82" title="0.015">ا</span><span style="background-color: hsl(120, 100.00%, 95.34%); opacity: 0.81" title="0.006">ر</span><span style="background-color: hsl(120, 100.00%, 90.15%); opacity: 0.83" title="0.018">ا</span><span style="background-color: hsl(120, 100.00%, 97.14%); opacity: 0.80" title="0.003">ه</span><span style="background-color: hsl(0, 100.00%, 88.47%); opacity: 0.83" title="-0.022"> </span><span style="background-color: hsl(0, 100.00%, 78.69%); opacity: 0.88" title="-0.054">ا</span><span style="background-color: hsl(0, 100.00%, 78.67%); opacity: 0.88" title="-0.054">ل</span><span style="ba ...
#     </p>
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Feel free to play with notebook explore different models with different datasets
